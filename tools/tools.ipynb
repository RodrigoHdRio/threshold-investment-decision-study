# %% [markdown]
# # Tools
# Shared imports, constants, and utility functions.

# %%
import pandas as pd
import numpy as np
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from scipy.stats import permutation_test, spearmanr
import numpy as np
import pandas as pd
from matplotlib.ticker import PercentFormatter
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from IPython.display import display
from sklearn.dummy import DummyRegressor
from itertools import combinations
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.transforms as mtransforms
import matplotlib.ticker as mtick



try:
    import yfinance as yf
except ImportError as error:
    raise ImportError("yfinance is required. Install with: pip install yfinance") from error

pd.set_option("display.max_columns", 50)

REQUIRED_COMPUSTAT_COLUMNS = ["tic", "fyear", "revenue", "net_income", "stockholders_equity"]
NUMERIC_COMPUSTAT_COLUMNS = ["fyear", "revenue", "net_income", "stockholders_equity"]
MODEL_FEATURE_COLUMNS = ["revenue_growth", "roe", "vol_60", "momentum_6_12"]
DECISION_THRESHOLDS = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]

LOOKBACK_BUFFER_DAYS = 400
PRICE_DOWNLOAD_CHUNK_SIZE = 50
REQUIRED_PRICE_FIELD = "Adj Close"

# %%
"""
Consistent schema regardless of CSV header formatting.
"""
def normalize_column_names(dataframe):
    standardized_dataframe = dataframe.copy()
    standardized_dataframe.columns = [
        column_name.strip().lower().replace(" ", "_")
        for column_name in standardized_dataframe.columns
    ]
    return standardized_dataframe

"""
Fail fast when the source dataset is missing required fields, rather than
letting later transformations break with less clear errors.
"""

def validate_required_columns(dataframe, required_columns):
    missing_columns = [column_name for column_name in required_columns if column_name not in dataframe.columns]
    if missing_columns:
        raise ValueError(f"Missing required columns: {missing_columns}")

"""
Break large ticker lists into smaller batches to keep Yahoo Finance requests
manageable and reduce the chance of partial download failures.
"""
def split_into_chunks(values, chunk_size):
    return [values[start:start + chunk_size] for start in range(0, len(values), chunk_size)]

"""
Normalize Yahoo Finance output into a plain adjusted-close matrix because the
library returns different column layouts for single-ticker and multi-ticker requests.
"""
def extract_price_field(price_dataframe, field_name=REQUIRED_PRICE_FIELD):
    if isinstance(price_dataframe.columns, pd.MultiIndex):
        if field_name in price_dataframe.columns.get_level_values(0):
            return price_dataframe.xs(field_name, axis=1, level=0).copy()
        if field_name in price_dataframe.columns.get_level_values(1):
            return price_dataframe.xs(field_name, axis=1, level=1).copy()

    if field_name in price_dataframe.columns:
        return price_dataframe[[field_name]].copy()

    raise RuntimeError(f"Required field '{field_name}' not found in Yahoo output.")


def percent_style(df, columns, decimals=2):
    fmt = {col: f"{{:.{decimals}%}}" for col in columns if col in df.columns}
    return df.style.format(fmt)

def percent_axes(x=False, y=False, decimals=0):
    ax = plt.gca()
    if x:
        ax.xaxis.set_major_formatter(PercentFormatter(1.0, decimals=decimals))
    if y:
        ax.yaxis.set_major_formatter(PercentFormatter(1.0, decimals=decimals))
    return ax


"""
Helpers for decision-error evaluation and summary-table construction.
"""
def calculate_rate(numerator, denominator):
    return numerator / denominator if denominator else np.nan


def count_negative_returns(actual_returns):
    return int((actual_returns < 0).sum())


def count_returns_below_threshold(actual_returns, threshold):
    return int((actual_returns < threshold).sum())


def count_returns_at_or_above_threshold(actual_returns, threshold):
    return int((actual_returns >= threshold).sum())


def count_loss_making_approvals(actual_returns, approve_mask):
    return int((approve_mask & (actual_returns < 0)).sum())


def count_threshold_type_i_errors(actual_returns, approve_mask, threshold):
    return int((approve_mask & (actual_returns < threshold)).sum())


def count_threshold_type_ii_errors(actual_returns, approve_mask, threshold):
    return int((~approve_mask & (actual_returns >= threshold)).sum())


def build_flip_direction_labels(linear_approve, random_forest_approve):
    return np.select(
        [
            linear_approve & (~random_forest_approve),
            (~linear_approve) & random_forest_approve,
        ],
        [
            "LR approve / RF reject",
            "RF approve / LR reject",
        ],
        default="Agree",
    )


def build_threshold_error_labels(actual_returns, threshold):
    return np.where(
        actual_returns < threshold,
        "Type I Error",
        "Type II Error",
    )


def build_flip_error_model_labels(flip_directions, error_types):
    error_model_lookup = {
        ("LR approve / RF reject", "Type I Error"): "LinearRegression",
        ("LR approve / RF reject", "Type II Error"): "RandomForest",
        ("RF approve / LR reject", "Type I Error"): "RandomForest",
        ("RF approve / LR reject", "Type II Error"): "LinearRegression",
    }

    return [
        error_model_lookup[(flip_direction, error_type)]
        for flip_direction, error_type in zip(flip_directions, error_types)
    ]


def build_summary_metric_table(results, values, decimals=None):
    metric_table = (
        results
        .pivot(
            index="threshold",
            columns="model",
            values=values,
        )
        .sort_index(axis=1, level=[0, 1])
    )

    if decimals is not None:
        metric_table = metric_table.round(decimals)

    metric_table.index = metric_table.index.map(lambda x: f"{x * 100:g}%")
    return metric_table
